# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train = pd.read_csv("../data/train_ZoGVYWq.csv")
test = pd.read_csv("../data/test_66516Ee.csv")
submission = pd.read_csv("../data/sample_submission_sLex1ul.csv")

# %% [markdown]
# # Setup Data

# %%
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.preprocessing import LabelEncoder,OneHotEncoder

# %%
#SETUP DATA
data = pd.concat([train, test], axis=0).reset_index(drop = True)
data["sourcing_channel"] = LabelEncoder().fit_transform(data["sourcing_channel"])
data["residence_area_type"] = LabelEncoder().fit_transform(data["residence_area_type"])

# %%
train = data[:train.shape[0]].reset_index(drop =True)
test = data[train.shape[0]:].reset_index(drop =True)

train_id = train[["id"]]
test_id = test[["id"]]
target = train.renewal

train = train.drop(["id","renewal"], axis=1)
test = test.drop(["id","renewal"], axis=1)

# %% [markdown]
# # Running  Model

# %%
import lightgbm as lgb
def model_lgb(x_train, x_test, y_train, y_test, test, meta_train, meta_test,train_index, test_index,fold_id):
    dtrain = lgb.Dataset(x_train, label=y_train,categorical_feature = ["sourcing_channel","residence_area_type"])
    dval = lgb.Dataset(x_test, label=y_test, categorical_feature = ["sourcing_channel","residence_area_type"])
    params = {
        "nthread":8,
        "bagging_fraction": 0.85,
        "feature_fraction": 0.85,
        "bagging_freq": 1,
        "metric":"auc",
        "objective": "binary",
        "learning_rate":0.15,
        "num_leaves":5,
        "max_depth":5,
        "silent":-1,
        "verbose":-1,
        "bagging_seed" : 3232424,
        "seed":4233242
    }
    model = lgb.train(params, dtrain, num_boost_round=5000,valid_sets=[dtrain, dval], early_stopping_rounds=200, verbose_eval=100)
    meta_train[test_index] = model.predict(x_test, num_iteration=model.best_iteration or 5000)
    meta_test.append(model.predict(test, num_iteration=model.best_iteration or 5000))
    
    global meta_train_tid
    meta_train_tid[train_index] = model.predict(x_train, num_iteration=model.best_iteration or 5000)

    # Calculate Feature Importance
    global feature_importance
    gain = model.feature_importance('gain')
    feature_importance = feature_importance.append(pd.DataFrame({'feature':model.feature_name(), 'split':model.feature_importance('split'), 'gain':100 * gain / gain.sum()}), ignore_index=True)

# %%
meta_train = np.zeros(train.shape[0])
meta_train_tid = np.zeros(train.shape[0])
meta_test = []
feature_importance = pd.DataFrame(columns = ["feature","split","gain"])

kf = StratifiedKFold(n_splits= 5, shuffle=True, random_state=4323324)
for fold_id, (train_index, test_index) in enumerate(kf.split(train, target)):
    x_train, x_test = train.iloc[train_index], train.iloc[test_index]
    y_train, y_test = target[train_index], target[test_index]

    model_lgb(x_train, x_test, y_train, y_test, test, meta_train, meta_test,train_index, test_index,fold_id)

print "Overall Score:", roc_auc_score(target, meta_train)

test_id["renewal"] = pd.DataFrame(np.array(meta_test).T).rank(pct = True, axis=0).mean(axis=1)
train_id["renewal"] = meta_train
train_id["renewal_tid"] = meta_train_tid
# Out:
# /anaconda2/lib/python2.7/site-packages/lightgbm/basic.py:1036: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# /anaconda2/lib/python2.7/site-packages/lightgbm/basic.py:657: UserWarning: silent keyword has been found in `params` and will be ignored. Please use silent argument of the Dataset constructor to pass this parameter.
#   'Please use {0} argument of the Dataset constructor to pass this parameter.'.format(key))
# /anaconda2/lib/python2.7/site-packages/lightgbm/basic.py:681: UserWarning: categorical_feature in param dict is overrided.
#   warnings.warn('categorical_feature in param dict is overrided.')
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.852989	valid_1's auc: 0.843217
# [200]	training's auc: 0.861952	valid_1's auc: 0.84111
# Early stopping, best iteration is:
# [71]	training's auc: 0.849263	valid_1's auc: 0.843586
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.852841	valid_1's auc: 0.844517
# [200]	training's auc: 0.861753	valid_1's auc: 0.842228
# [300]	training's auc: 0.870081	valid_1's auc: 0.841056
# Early stopping, best iteration is:
# [105]	training's auc: 0.853224	valid_1's auc: 0.844755
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.854418	valid_1's auc: 0.841128
# [200]	training's auc: 0.863294	valid_1's auc: 0.840498
# Early stopping, best iteration is:
# [76]	training's auc: 0.850962	valid_1's auc: 0.841722
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.855208	valid_1's auc: 0.838448
# [200]	training's auc: 0.864322	valid_1's auc: 0.838536
# [300]	training's auc: 0.871242	valid_1's auc: 0.836149
# Early stopping, best iteration is:
# [122]	training's auc: 0.857069	valid_1's auc: 0.838966
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.851476	valid_1's auc: 0.845935
# [200]	training's auc: 0.859781	valid_1's auc: 0.845083
# [300]	training's auc: 0.867421	valid_1's auc: 0.845605
# Early stopping, best iteration is:
# [104]	training's auc: 0.851874	valid_1's auc: 0.846437
# Overall Score: 0.843044768505

# %%
# Print Feature Importance
feature_importance = feature_importance.groupby("feature")["gain"].mean().reset_index().sort_values('gain', ascending=False).reset_index(drop=True)
plt.figure()
feature_importance[['feature','gain']].head(60).plot(kind='barh', x='feature', y='gain', legend=False, figsize=(20, 10));

# %% [markdown]
# # Working on Incentives

# %%
def get_effort(incentive):
    return 10*(1-np.exp(-incentive/400.0))
    
def get_improvement_in_renewal_probability(incentive):
    effort = get_effort(incentive)
    return 20*(1-np.exp(-effort/5.0))

def gradient_improvement_in_renewal_probability(incentive):
    dpde = 4 * np.exp(-get_effort(incentive)/5.0)
    dedi = np.exp(-incentive/400.0)/40.0
    dpdi = dpde * dedi
    return  dpdi
    
def revenue_score(incentive, benchmark, premium):
    cdp = get_improvement_in_renewal_probability(incentive)
    profits = ((benchmark + (cdp*benchmark/100.0)) * premium)-incentive
    return np.sum(profits)

def score_gradient(incentive, benchmark, premium):
    z=  np.exp(-incentive/400.0)-(incentive/400.0)-2
    return ((benchmark * premium * np.exp(z)/400.0)-1)

def second_score_gradient(incentive, benchmark, premium):
    a = np.exp(-incentive/400.0)-(incentive/400.0)
    b = (benchmark* premium* np.exp(a))/400.0
    return (-(b)-(1.0/400.0))/400.0

def learn(benchmark, premium, early_stopping = 5, start_incentive = 1700, min_improvement = 0.005, verbose = True):
    incentive = start_incentive
    best_incentive = start_incentive
    
    score = 0
    best_score = 0
    
    counter = 0
    best_counter = 0
    no_improvement_counter = 0
    
    while True:
        lr = (incentive - 0)
        gradient = score_gradient(incentive, benchmark, premium)
        try:
            incentive += lr*(gradient*0.5 + 0.5*prev_gradient)
        except:
            incentive += lr*gradient
            
        
        score = revenue_score(incentive, benchmark, premium)
        counter +=1
        prev_gradient = gradient

        if (score-best_score> min_improvement):
            best_score = score
            best_incentive = incentive
            best_counter = counter
            
            no_improvement_counter = 0
            if verbose: print "Epoch: {}, Incentive: {}, Score: {}, Gradient: {}".format(counter,incentive, score, gradient)
        else:
            if (no_improvement_counter > early_stopping):
                if verbose: print "Early Stopping, Best Iteration Round: {}".format(best_counter)
                return best_incentive, best_score
            else:
                no_improvement_counter +=1
                if verbose: print "Epoch: {}, Incentive: {}, Score: {}, Gradient: {}".format(counter,incentive, score, gradient)

# %%
def annealing(benchmark, premium, num_annealing = 30):
    results = []
    for incentive in range(0,premium,int(float(premium)/num_annealing)):
        results.append(learn(benchmark, premium, early_stopping = 5, start_incentive = incentive, min_improvement = 0.005, verbose = False))
    return sorted(results, key = lambda x: x[1])[-1][0]

# %%
train_incentives = []

for i, (benchmark, premium) in enumerate(zip(train_id["renewal_tid"], train["premium"])):
    if i%10000 == 0: print "Completed {} Rows".format(i)
    train_incentives.append(annealing(benchmark, premium))
    
train_incentives = pd.Series(train_incentives)
train_incentives[train_incentives<0] = 0

generated_score = revenue_score(train_incentives, train_id["renewal_tid"], train["premium"])
baseline_score = revenue_score(pd.Series([1650]*len(train_incentives)), train_id["renewal_tid"], train["premium"])

print "Score using generated Incentive:",generated_score
print "Score using 1650 as Incentive:",baseline_score
print "Score Improvement:", generated_score/baseline_score
# Out:
# Completed 0 Rows
# Completed 10000 Rows
# Completed 20000 Rows
# Completed 30000 Rows
# Completed 40000 Rows
# Completed 50000 Rows
# Completed 60000 Rows
# Completed 70000 Rows
# Score using generated Incentive: 917182487.635
# Score using 1650 as Incentive: 834707165.907
# Score Improvement: 1.09880749213

# %%
test_incentives = []

for i, (benchmark, premium) in enumerate(zip(test_id["renewal"], test["premium"])):
    if i%10000 == 0: print "Completed {} Rows".format(i)
    test_incentives.append(annealing(benchmark, premium))
    
test_incentives = pd.Series(test_incentives)
test_incentives[test_incentives<0] = 0

generated_score = revenue_score(test_incentives, test_id["renewal"], test["premium"])
baseline_score = revenue_score(pd.Series([1650]*len(test_incentives)), test_id["renewal"], test["premium"])

print "Score using generated Incentive:",generated_score
print "Score using 1650 as Incentive:",baseline_score
print "Score Improvement:", generated_score/baseline_score
# Out:
# Completed 0 Rows
# Completed 10000 Rows
# Completed 20000 Rows
# Completed 30000 Rows
# Score using generated Incentive: 214842022.503
# Score using 1650 as Incentive: 173048573.389
# Score Improvement: 1.24151282091

# %% [markdown]
# # Training for Incentives

# %%
import lightgbm as lgb
from sklearn.metrics import mean_squared_error

def model_lgb_regression(x_train, x_test, y_train, y_test, test, meta_train, meta_test,train_index, test_index,fold_id):
    dtrain = lgb.Dataset(x_train, label=y_train)
    dval = lgb.Dataset(x_test, label=y_test)
    params = {
        "nthread":8,
        "bagging_fraction": 0.85,
        "feature_fraction": 0.85,
        "bagging_freq": 1,
        "metric":"rmse",
        "objective": "regression",
        "learning_rate":0.05,
        "num_leaves":10,
        "max_depth":10,
        "silent":-1,
        "verbose":-1,
        "bagging_seed" : 53443,
        "seed":2423
    }
    model = lgb.train(params, dtrain, num_boost_round=5000,valid_sets=[dtrain, dval], early_stopping_rounds=200, verbose_eval=100)
    meta_train[test_index] = model.predict(x_test, num_iteration=model.best_iteration or 5000)
    meta_test.append(model.predict(test, num_iteration=model.best_iteration or 5000))

    # Calculate Feature Importance
    global feature_importance
    gain = model.feature_importance('gain')
    feature_importance = feature_importance.append(pd.DataFrame({'feature':model.feature_name(), 'split':model.feature_importance('split'), 'gain':100 * gain / gain.sum()}), ignore_index=True)

# %%
train["prediction"] = train_id["renewal"]
test["prediction"] = train_id["renewal"]

meta_train = np.zeros(train.shape[0])
meta_test = []
feature_importance = pd.DataFrame(columns = ["feature","split","gain"])

kf = StratifiedKFold(n_splits= 5, shuffle=True, random_state=1232)
for fold_id, (train_index, test_index) in enumerate(kf.split(train, target)):
    x_train, x_test = train.iloc[train_index], train.iloc[test_index]
    y_train, y_test = train_incentives[train_index], train_incentives[test_index]

    model_lgb_regression(x_train, x_test, y_train, y_test, test, meta_train, meta_test,train_index, test_index,fold_id)

print "Overall Score:", mean_squared_error(train_incentives, meta_train)
test_id["incentives"] = np.array(meta_test).T.mean(axis=1)
train_id["incentives"] = meta_train

test_id["incentives"] += test_incentives
test_id["incentives"] /= 2
# Out:
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 12.1304	valid_1's rmse: 12.6193
# [200]	training's rmse: 9.27573	valid_1's rmse: 9.95147
# [300]	training's rmse: 8.60993	valid_1's rmse: 9.49763
# [400]	training's rmse: 8.21044	valid_1's rmse: 9.33218
# [500]	training's rmse: 7.93752	valid_1's rmse: 9.24263
# [600]	training's rmse: 7.70853	valid_1's rmse: 9.16468
# [700]	training's rmse: 7.50894	valid_1's rmse: 9.12754
# [800]	training's rmse: 7.33434	valid_1's rmse: 9.08481
# [900]	training's rmse: 7.18343	valid_1's rmse: 9.04057
# [1000]	training's rmse: 7.02928	valid_1's rmse: 8.99766
# [1100]	training's rmse: 6.89525	valid_1's rmse: 8.96384
# [1200]	training's rmse: 6.77172	valid_1's rmse: 8.92956
# [1300]	training's rmse: 6.66261	valid_1's rmse: 8.90549
# [1400]	training's rmse: 6.55543	valid_1's rmse: 8.89327
# [1500]	training's rmse: 6.46109	valid_1's rmse: 8.87332
# [1600]	training's rmse: 6.3723	valid_1's rmse: 8.8576
# [1700]	training's rmse: 6.28777	valid_1's rmse: 8.831
# [1800]	training's rmse: 6.21073	valid_1's rmse: 8.82332
# [1900]	training's rmse: 6.13163	valid_1's rmse: 8.79163
# [2000]	training's rmse: 6.05584	valid_1's rmse: 8.77277
# [2100]	training's rmse: 5.98442	valid_1's rmse: 8.76589
# [2200]	training's rmse: 5.9155	valid_1's rmse: 8.74183
# [2300]	training's rmse: 5.8518	valid_1's rmse: 8.73157
# [2400]	training's rmse: 5.79015	valid_1's rmse: 8.73585
# [2500]	training's rmse: 5.73242	valid_1's rmse: 8.72517
# [2600]	training's rmse: 5.67507	valid_1's rmse: 8.72154
# [2700]	training's rmse: 5.62065	valid_1's rmse: 8.70692
# [2800]	training's rmse: 5.56716	valid_1's rmse: 8.70166
# [2900]	training's rmse: 5.51274	valid_1's rmse: 8.69051
# [3000]	training's rmse: 5.46094	valid_1's rmse: 8.68365
# [3100]	training's rmse: 5.41233	valid_1's rmse: 8.68185
# [3200]	training's rmse: 5.36353	valid_1's rmse: 8.67654
# [3300]	training's rmse: 5.31662	valid_1's rmse: 8.66736
# [3400]	training's rmse: 5.26988	valid_1's rmse: 8.66242
# [3500]	training's rmse: 5.22464	valid_1's rmse: 8.66041
# [3600]	training's rmse: 5.18117	valid_1's rmse: 8.65447
# [3700]	training's rmse: 5.13473	valid_1's rmse: 8.65329
# [3800]	training's rmse: 5.09348	valid_1's rmse: 8.65028
# [3900]	training's rmse: 5.0517	valid_1's rmse: 8.64597
# [4000]	training's rmse: 5.01135	valid_1's rmse: 8.63546
# [4100]	training's rmse: 4.97015	valid_1's rmse: 8.63438
# [4200]	training's rmse: 4.9315	valid_1's rmse: 8.63701
# Early stopping, best iteration is:
# [4075]	training's rmse: 4.98384	valid_1's rmse: 8.63013
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 12.2109	valid_1's rmse: 12.3097
# [200]	training's rmse: 9.34952	valid_1's rmse: 9.64805
# [300]	training's rmse: 8.68165	valid_1's rmse: 9.19021
# [400]	training's rmse: 8.28586	valid_1's rmse: 8.99844
# [500]	training's rmse: 7.98881	valid_1's rmse: 8.8827
# [600]	training's rmse: 7.7573	valid_1's rmse: 8.80217
# [700]	training's rmse: 7.54306	valid_1's rmse: 8.75447
# [800]	training's rmse: 7.35538	valid_1's rmse: 8.70037
# [900]	training's rmse: 7.20142	valid_1's rmse: 8.6674
# [1000]	training's rmse: 7.05198	valid_1's rmse: 8.63042
# [1100]	training's rmse: 6.91015	valid_1's rmse: 8.59311
# [1200]	training's rmse: 6.78773	valid_1's rmse: 8.56539
# [1300]	training's rmse: 6.67083	valid_1's rmse: 8.54169
# [1400]	training's rmse: 6.56563	valid_1's rmse: 8.51804
# [1500]	training's rmse: 6.45742	valid_1's rmse: 8.50084
# [1600]	training's rmse: 6.3683	valid_1's rmse: 8.48415
# [1700]	training's rmse: 6.279	valid_1's rmse: 8.47609
# [1800]	training's rmse: 6.20025	valid_1's rmse: 8.45659
# [1900]	training's rmse: 6.1272	valid_1's rmse: 8.43653
# [2000]	training's rmse: 6.05483	valid_1's rmse: 8.4332
# [2100]	training's rmse: 5.98152	valid_1's rmse: 8.42623
# [2200]	training's rmse: 5.91099	valid_1's rmse: 8.42171
# [2300]	training's rmse: 5.84648	valid_1's rmse: 8.4142
# [2400]	training's rmse: 5.78569	valid_1's rmse: 8.4029
# [2500]	training's rmse: 5.72568	valid_1's rmse: 8.39414
# [2600]	training's rmse: 5.66323	valid_1's rmse: 8.38906
# [2700]	training's rmse: 5.60975	valid_1's rmse: 8.38099
# [2800]	training's rmse: 5.55543	valid_1's rmse: 8.37814
# [2900]	training's rmse: 5.50179	valid_1's rmse: 8.38004
# [3000]	training's rmse: 5.45034	valid_1's rmse: 8.36594
# [3100]	training's rmse: 5.39854	valid_1's rmse: 8.35809
# [3200]	training's rmse: 5.34985	valid_1's rmse: 8.35832
# [3300]	training's rmse: 5.29884	valid_1's rmse: 8.35065
# [3400]	training's rmse: 5.24968	valid_1's rmse: 8.34444
# [3500]	training's rmse: 5.2085	valid_1's rmse: 8.34041
# [3600]	training's rmse: 5.16301	valid_1's rmse: 8.33323
# [3700]	training's rmse: 5.11753	valid_1's rmse: 8.33456
# [3800]	training's rmse: 5.07291	valid_1's rmse: 8.33183
# [3900]	training's rmse: 5.03367	valid_1's rmse: 8.32832
# [4000]	training's rmse: 4.99195	valid_1's rmse: 8.32718
# [4100]	training's rmse: 4.95491	valid_1's rmse: 8.32704
# [4200]	training's rmse: 4.91712	valid_1's rmse: 8.31917
# [4300]	training's rmse: 4.87869	valid_1's rmse: 8.31678
# [4400]	training's rmse: 4.83697	valid_1's rmse: 8.31736
# Early stopping, best iteration is:
# [4258]	training's rmse: 4.89576	valid_1's rmse: 8.31426
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 12.2406	valid_1's rmse: 12.2301
# [200]	training's rmse: 9.36525	valid_1's rmse: 9.53067
# [300]	training's rmse: 8.70282	valid_1's rmse: 9.05199
# [400]	training's rmse: 8.30819	valid_1's rmse: 8.87116
# [500]	training's rmse: 8.01721	valid_1's rmse: 8.74498
# [600]	training's rmse: 7.7727	valid_1's rmse: 8.65463
# [700]	training's rmse: 7.56542	valid_1's rmse: 8.5947
# [800]	training's rmse: 7.38222	valid_1's rmse: 8.54468
# [900]	training's rmse: 7.21466	valid_1's rmse: 8.5018
# [1000]	training's rmse: 7.06405	valid_1's rmse: 8.46756
# [1100]	training's rmse: 6.93021	valid_1's rmse: 8.44689
# [1200]	training's rmse: 6.80705	valid_1's rmse: 8.41106
# [1300]	training's rmse: 6.6875	valid_1's rmse: 8.40514
# [1400]	training's rmse: 6.57384	valid_1's rmse: 8.38833
# [1500]	training's rmse: 6.46489	valid_1's rmse: 8.36962
# [1600]	training's rmse: 6.36806	valid_1's rmse: 8.35954
# [1700]	training's rmse: 6.27901	valid_1's rmse: 8.34984
# [1800]	training's rmse: 6.18894	valid_1's rmse: 8.33472
# [1900]	training's rmse: 6.10875	valid_1's rmse: 8.33033
# [2000]	training's rmse: 6.03161	valid_1's rmse: 8.31992
# [2100]	training's rmse: 5.96009	valid_1's rmse: 8.30656
# [2200]	training's rmse: 5.89212	valid_1's rmse: 8.29727
# [2300]	training's rmse: 5.82311	valid_1's rmse: 8.30037
# [2400]	training's rmse: 5.75817	valid_1's rmse: 8.29852
# [2500]	training's rmse: 5.69415	valid_1's rmse: 8.29527
# [2600]	training's rmse: 5.63986	valid_1's rmse: 8.29161
# [2700]	training's rmse: 5.57959	valid_1's rmse: 8.28488
# [2800]	training's rmse: 5.52298	valid_1's rmse: 8.28575
# [2900]	training's rmse: 5.46996	valid_1's rmse: 8.27993
# [3000]	training's rmse: 5.42162	valid_1's rmse: 8.27871
# Early stopping, best iteration is:
# [2864]	training's rmse: 5.48923	valid_1's rmse: 8.2742
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 12.217	valid_1's rmse: 12.5099
# [200]	training's rmse: 9.27845	valid_1's rmse: 9.98542
# [300]	training's rmse: 8.60247	valid_1's rmse: 9.62962
# [400]	training's rmse: 8.17799	valid_1's rmse: 9.45791
# [500]	training's rmse: 7.87693	valid_1's rmse: 9.37396
# [600]	training's rmse: 7.64022	valid_1's rmse: 9.32902
# [700]	training's rmse: 7.44028	valid_1's rmse: 9.28578
# [800]	training's rmse: 7.26894	valid_1's rmse: 9.2404
# [900]	training's rmse: 7.10344	valid_1's rmse: 9.20501
# [1000]	training's rmse: 6.94683	valid_1's rmse: 9.18412
# [1100]	training's rmse: 6.81726	valid_1's rmse: 9.1556
# [1200]	training's rmse: 6.70308	valid_1's rmse: 9.14537
# [1300]	training's rmse: 6.59675	valid_1's rmse: 9.12607
# [1400]	training's rmse: 6.48946	valid_1's rmse: 9.12805
# [1500]	training's rmse: 6.39235	valid_1's rmse: 9.11823
# [1600]	training's rmse: 6.2937	valid_1's rmse: 9.09472
# [1700]	training's rmse: 6.20507	valid_1's rmse: 9.0867
# [1800]	training's rmse: 6.12923	valid_1's rmse: 9.07385
# [1900]	training's rmse: 6.05216	valid_1's rmse: 9.05649
# [2000]	training's rmse: 5.98316	valid_1's rmse: 9.05225
# [2100]	training's rmse: 5.91093	valid_1's rmse: 9.04249
# [2200]	training's rmse: 5.8423	valid_1's rmse: 9.03477
# [2300]	training's rmse: 5.78339	valid_1's rmse: 9.02767
# [2400]	training's rmse: 5.72151	valid_1's rmse: 9.01738
# [2500]	training's rmse: 5.66435	valid_1's rmse: 9.00994
# [2600]	training's rmse: 5.60556	valid_1's rmse: 8.99828
# [2700]	training's rmse: 5.55044	valid_1's rmse: 9.00045
# Early stopping, best iteration is:
# [2595]	training's rmse: 5.6084	valid_1's rmse: 8.99757
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 12.2067	valid_1's rmse: 12.3316
# [200]	training's rmse: 9.41625	valid_1's rmse: 9.56659
# [300]	training's rmse: 8.75306	valid_1's rmse: 9.05899
# [400]	training's rmse: 8.34861	valid_1's rmse: 8.81876
# [500]	training's rmse: 8.06698	valid_1's rmse: 8.67259
# [600]	training's rmse: 7.83489	valid_1's rmse: 8.57713
# [700]	training's rmse: 7.62014	valid_1's rmse: 8.4843
# [800]	training's rmse: 7.43476	valid_1's rmse: 8.43276
# [900]	training's rmse: 7.28005	valid_1's rmse: 8.37527
# [1000]	training's rmse: 7.13259	valid_1's rmse: 8.33047
# [1100]	training's rmse: 6.99826	valid_1's rmse: 8.29654
# [1200]	training's rmse: 6.86837	valid_1's rmse: 8.25741
# [1300]	training's rmse: 6.74948	valid_1's rmse: 8.23151
# [1400]	training's rmse: 6.63616	valid_1's rmse: 8.20183
# [1500]	training's rmse: 6.52864	valid_1's rmse: 8.17171
# [1600]	training's rmse: 6.44336	valid_1's rmse: 8.15582
# [1700]	training's rmse: 6.35398	valid_1's rmse: 8.13993
# [1800]	training's rmse: 6.26587	valid_1's rmse: 8.11786
# [1900]	training's rmse: 6.18813	valid_1's rmse: 8.09692
# [2000]	training's rmse: 6.10754	valid_1's rmse: 8.09077
# [2100]	training's rmse: 6.04077	valid_1's rmse: 8.07301
# [2200]	training's rmse: 5.97334	valid_1's rmse: 8.07143
# [2300]	training's rmse: 5.9051	valid_1's rmse: 8.05142
# [2400]	training's rmse: 5.84203	valid_1's rmse: 8.02865
# [2500]	training's rmse: 5.78167	valid_1's rmse: 8.02261
# [2600]	training's rmse: 5.71887	valid_1's rmse: 8.00915
# [2700]	training's rmse: 5.66234	valid_1's rmse: 7.99787
# [2800]	training's rmse: 5.60501	valid_1's rmse: 7.99127
# [2900]	training's rmse: 5.55349	valid_1's rmse: 7.9822
# [3000]	training's rmse: 5.50222	valid_1's rmse: 7.97579
# [3100]	training's rmse: 5.45397	valid_1's rmse: 7.97539
# [3200]	training's rmse: 5.40675	valid_1's rmse: 7.9694
# [3300]	training's rmse: 5.36147	valid_1's rmse: 7.95879
# [3400]	training's rmse: 5.31712	valid_1's rmse: 7.9497
# [3500]	training's rmse: 5.27251	valid_1's rmse: 7.94334
# [3600]	training's rmse: 5.22968	valid_1's rmse: 7.93448
# [3700]	training's rmse: 5.18452	valid_1's rmse: 7.92796
# [3800]	training's rmse: 5.14321	valid_1's rmse: 7.92506
# [3900]	training's rmse: 5.10242	valid_1's rmse: 7.92304
# [4000]	training's rmse: 5.06246	valid_1's rmse: 7.92454
# [4100]	training's rmse: 5.0212	valid_1's rmse: 7.91808
# [4200]	training's rmse: 4.98364	valid_1's rmse: 7.91955
# [4300]	training's rmse: 4.94758	valid_1's rmse: 7.91001
# [4400]	training's rmse: 4.91133	valid_1's rmse: 7.90763
# [4500]	training's rmse: 4.87479	valid_1's rmse: 7.90824
# Early stopping, best iteration is:
# [4324]	training's rmse: 4.93871	valid_1's rmse: 7.9068
# Overall Score: 71.1084185391

# %%
# Print Feature Importance
feature_importance = feature_importance.groupby("feature")["gain"].mean().reset_index().sort_values('gain', ascending=False).reset_index(drop=True)
plt.figure()
feature_importance[['feature','gain']].head(60).plot(kind='barh', x='feature', y='gain', legend=False, figsize=(20, 10));

# %%
submission = submission[["id"]].merge(test_id[["id","renewal","incentives"]], how = "left", on = "id")
submission = submission[["id", "renewal", "incentives"]]
submission.loc[submission.incentives < 0,"incentives"] = 0
submission.to_csv("csv/eda9.csv", index=False)

# %%
submission
# Out:
#            id   renewal  incentives
# 0         649  0.856980  168.728556
# 1       81136  0.683643  400.971293
# 2       70762  0.144410  198.570000
# 3       53935  0.502752  210.496933
# 4       15476  0.395716  303.681780
# 5       64797  0.719764  398.565645
# 6       67412  0.074731   79.879089
# 7       44241  0.073422   84.576019
# 8        5069  0.866036  464.968605
# 9       16615  0.926858  677.699525
# 10      84281  0.797677  553.258104
# 11      82623  0.416585    9.593113
# 12      86475  0.028156  175.353568
# 13      68263  0.360215   10.513239
# 14     113135  0.312997    6.552475
# 15      45532  0.481709  449.497067
# 16     102161  0.986559  341.659530
# 17      84789  0.037921  335.918694
# 18      62398  0.498524  367.287177
# 19      70148  0.703208  145.795391
# 20     102487  0.232766  323.695812
# 21     100513  0.187120  273.912075
# 22      92702  0.164861  138.699275
# 23      25051  0.038286  158.550505
# 24      92920  0.913143  471.153703
# 25      25520  0.377712  338.787558
# 26      81869  0.404982  638.134458
# 27      75402  0.719147  307.731208
# 28      34053  0.027215    4.617006
# 29      21191  0.770705  368.953205
# ...       ...       ...         ...
# 34194   79950  0.755020  304.097014
# 34195   30272  0.919007   18.546092
# 34196   85914  0.993545  484.344984
# 34197   10922  0.742751  446.349352
# 34198   93046  0.746353  232.146472
# 34199   52826  0.321476  420.749454
# 34200   35994  0.701999  652.661522
# 34201    1512  0.763406  246.812361
# 34202   52077  0.435528  248.409113
# 34203   95749  0.585238  285.435083
# 34204   49946  0.730131  152.053416
# 34205   66811  0.664969  352.235366
# 34206   53438  0.936711   17.417043
# 34207   24435  0.724252  535.193166
# 34208   17848  0.509540  387.755240
# 34209   53626  0.616927  228.717271
# 34210   87268  0.902951  473.038752
# 34211   58450  0.564960    9.522662
# 34212   48188  0.679970  581.781959
# 34213   44239  0.494156  362.904604
# 34214   24582  0.268259  215.860853
# 34215   79939  0.384724  103.220456
# 34216   63759  0.441731   11.050390
# 34217   63725  0.039317   80.560337
# 34218   37116  0.408728  479.514295
# 34219   81988  0.442169  195.519973
# 34220   30326  0.606589    5.717328
# 34221   65749  0.319928    9.118784
# 34222   65686  0.054862  231.277385
# 34223   93826  0.381270  145.121548
#
# [34224 rows x 3 columns]
